# %%
#Process RTS sample scenarios to understand input-output relationship between RTS scenarios and Vatic outputs:
#(i) total daily system costs; (ii) lost load; (iii) renewable curtailment.
#coverts pickle files to csv files
import bz2
import dill as pickle
import pandas as pd
import csv
#pd.set_option(pat, value)
pd.options.display.max_rows
pd.options.display.max_columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', -1)
out_file = "daily_summary.p.gz"
with bz2.BZ2File(out_file, "rb") as f:
    day_scens = pickle.load(f)
    #print(day_scens[])
df = pd.DataFrame([day_scens])
print(dict.keys(day_scens))
LoadShedding=day_scens[ (('309_WIND_1', '317_WIND_1', '303_WIND_1', '122_WIND_1'),)]['Load shedding']
#print(LoadShedding)
LoadShedding.to_csv('LoadSheddingJanuary20.csv')
GenerationCost=day_scens[ (('309_WIND_1', '317_WIND_1', '303_WIND_1', '122_WIND_1'),)]['Generation costs']
#print(GenerationCost)
GenerationCost.to_csv('GenerationCostJanuary20.csv')
#RenewablesCurtailment=day_scens[(('308_RTPV_1', '313_RTPV_1', '313_RTPV_2', '313_RTPV_3', '313_RTPV_4', '313_RTPV_5', '313_RTPV_6', '313_RTPV_7', '313_RTPV_8', '313_RTPV_9', '313_RTPV_10', '313_RTPV_11', '313_RTPV_12', '320_RTPV_1', '320_RTPV_2', '320_RTPV_3', '313_RTPV_13', '320_RTPV_4', '320_RTPV_5', '118_RTPV_1', '118_RTPV_2', '118_RTPV_3', '118_RTPV_4', '118_RTPV_5', '118_RTPV_6', '320_RTPV_6', '118_RTPV_7', '118_RTPV_8', '118_RTPV_9', '118_RTPV_10', '213_RTPV_1'), ('309_WIND_1', '317_WIND_1', '303_WIND_1', '122_WIND_1'), ('320_PV_1', '314_PV_1', '314_PV_2', '313_PV_1', '314_PV_3', '314_PV_4', '313_PV_2', '310_PV_1', '324_PV_1', '312_PV_1', '310_PV_2', '324_PV_2', '324_PV_3', '113_PV_1', '319_PV_1', '215_PV_1', '102_PV_1', '101_PV_1', '102_PV_2', '104_PV_1', '101_PV_2', '101_PV_3', '101_PV_4', '103_PV_1', '119_PV_1'))]['Renewables curtailment']
RenewableCurtailment=day_scens[ (('309_WIND_1', '317_WIND_1', '303_WIND_1', '122_WIND_1'),)]['Renewables curtailment']
#print(RenewablesCurtailment)
RenewableCurtailment.to_csv('RenewablesCurtailmentJanuary20.csv')
# Out:
# dict_keys([(), (('308_RTPV_1', '313_RTPV_1', '313_RTPV_2', '313_RTPV_3', '313_RTPV_4', '313_RTPV_5', '313_RTPV_6', '313_RTPV_7', '313_RTPV_8', '313_RTPV_9', '313_RTPV_10', '313_RTPV_11', '313_RTPV_12', '320_RTPV_1', '320_RTPV_2', '320_RTPV_3', '313_RTPV_13', '320_RTPV_4', '320_RTPV_5', '118_RTPV_1', '118_RTPV_2', '118_RTPV_3', '118_RTPV_4', '118_RTPV_5', '118_RTPV_6', '320_RTPV_6', '118_RTPV_7', '118_RTPV_8', '118_RTPV_9', '118_RTPV_10', '213_RTPV_1'), ('320_PV_1', '314_PV_1', '314_PV_2', '313_PV_1', '314_PV_3', '314_PV_4', '313_PV_2', '310_PV_1', '324_PV_1', '312_PV_1', '310_PV_2', '324_PV_2', '324_PV_3', '113_PV_1', '319_PV_1', '215
#print(RenewablesCurtailment)
RenewableCurtailmentSolar.to_csv('RenewablesCurtailmentSolarJanuary20.csv')

# %%
#bars = np.linspace(0.9,1,25)
# print(bars)
# plt.figure()
# plt.hist(load_daily_coverage_asset_lvl_mean_by_days, bars)
import matplotlib.pyplot as plt
#plt.figure()
fig = plt.figure(figsize=(15,3))
ax = fig.add_subplot(1,3,1)
ax.set_ylabel("Generation Cost",fontsize=15)
ax.hist(GenerationCost)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,2)
ax.set_ylabel("Load Shedding",fontsize=15)
ax.hist(LoadShedding)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,3)
ax.hist(RenewableCurtailment)
plt.ylabel("Renewable Cirtailment",fontsize=15)
ax.tick_params(labelsize=15)
#plt.xlim([0.95, 1.02])
#plt.xlabel("Proportion of Assets Covering Realizations From Below")
#plt.ylabel("Count")
#plt.title("Histogram of Wind Coverage From Below at Asset Level (ORFEUS)")
#plt.savefig("C:\\Users\\Mahashweta Patra\\Documents\\MikeLudkovski\\Output\\Percentiles\\IntraDayNew1\\Figure\\HistogramWindCoverageIntraDayNew1.png", dpi=300)
plt.tight_layout()
plt.savefig("C:\\Users\\Mahashweta Patra\\Documents\\MikeLudkovski\\ORFEUSRTS\\type-pwrset-jan20-20211229T210546Z-001\\type-pwrset-jan20\\Figures\\WindVaticOutput.png", dpi=300)

# %%
#bars = np.linspace(0.9,1,25)
# print(bars)
# plt.figure()
# plt.hist(load_daily_coverage_asset_lvl_mean_by_days, bars)
import matplotlib.pyplot as plt
#plt.figure()
fig = plt.figure(figsize=(15,3))
ax = fig.add_subplot(1,3,1)
ax.set_ylabel("Generation Cost Solar",fontsize=15)
ax.hist(GenerationCostSolar)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,2)
ax.set_ylabel("Load Shedding Solar",fontsize=15)
ax.hist(LoadSheddingSolar)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,3)
ax.hist(RenewableCurtailmentSolar)
ax.set_ylabel("Renewable Cirtailment Solar",fontsize=15)
ax.tick_params(labelsize=15)
#plt.xlim([0.95, 1.02])
#plt.xlabel("Proportion of Assets Covering Realizations From Below")
#plt.ylabel("Count")
#plt.title("Histogram of Wind Coverage From Below at Asset Level (ORFEUS)")
#plt.savefig("C:\\Users\\Mahashweta Patra\\Documents\\MikeLudkovski\\Output\\Percentiles\\IntraDayNew1\\Figure\\HistogramWindCoverageIntraDayNew1.png", dpi=300)
plt.tight_layout()
plt.savefig("C:\\Users\\Mahashweta Patra\\Documents\\MikeLudkovski\\ORFEUSRTS\\type-pwrset-jan20-20211229T210546Z-001\\type-pwrset-jan20\\Figures\\SolarVaticOutput.png", dpi=300)

# %%
import statistics
arithmeticMean = statistics.mean(GenerationCost)
print('Mean of the distribution is', arithmeticMean)
Var=statistics.pvariance(GenerationCost)
print('Variance of the distribution is',Var)
HigherGen=[]
for i in range(0,1000):
    a=GenerationCost[i]
    if (a>340000.0):
        HigherGen.append(GenerationCost[i])
print('Number of Higher generation costs are',len(HigherGen))
# Out:
# Mean of the distribution is 322500.861957242
# Variance of the distribution is 251126446.03456086
# Number of Higher generation costs are 131

# %%
import bz2
import dill as pickle
import pandas as pd
import csv
#pd.set_option(pat, value)
pd.options.display.max_rows
pd.options.display.max_columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', -1)
out_file = "scens_2020-01-20.p.gz"
with bz2.BZ2File(out_file, "rb") as f:
    scenarios = pickle.load(f)
    #print(day_scens[])
df = pd.DataFrame([scenarios])
print(dict.keys(scenarios))
#scenarios
WindScenarios=scenarios['Wind']['309_WIND_1']+scenarios['Wind']['303_WIND_1']+scenarios['Wind']['122_WIND_1']+scenarios['Wind']['317_WIND_1']
#['303_WIND_1']
#['122_WIND_1']
#print(WindScenarios)
WindScenarios.to_csv('WindScenariosAggregated.csv')
SolarAsset=['320_PV_1', '314_PV_1', '314_PV_2', '313_PV_1', '314_PV_3', '314_PV_4', '313_PV_2', '310_PV_1', '324_PV_1', '312_PV_1', '310_PV_2', '324_PV_2', '324_PV_3', '113_PV_1', '319_PV_1', '215_PV_1', '102_PV_1', '101_PV_1', '102_PV_2', '104_PV_1', '101_PV_2', '101_PV_3', '101_PV_4', '103_PV_1', '119_PV_1']
print(len(SolarAsset))
SolarScenarios=scenarios['Solar'][SolarAsset[0]]
for i in range(1,25):
    SolarScenariosNew=scenarios['Solar'][SolarAsset[i]]
    SolarScenarios=SolarScenarios+SolarScenariosNew
    SolarScenariosNew.to_csv('SolarScenario'+str(i)+'.csv')
#print(SolarScenarios)
SolarScenarios.to_csv('SolarScenariosAggregated.csv')
LoadScenarios=scenarios['Load']['1']+scenarios['Load']['2']+scenarios['Load']['3']
# Out:
# dict_keys(['Wind', 'Load', 'Solar'])
# 25

# %%
import matplotlib.pyplot as plt
#plt.figure()
fig = plt.figure(figsize=(15,3))
ax = fig.add_subplot(1,3,1)
ax.set_ylabel("Wind Scenarios",fontsize=15)
plt.plot(WindScenarios.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,2)
ax.set_ylabel("Solar Scenarios",fontsize=15)
plt.plot(SolarScenarios.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,3)
ax.set_ylabel("Load Scenarios",fontsize=15)
plt.plot(LoadScenarios.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

#plt.ylim([0.8, 1.02])
#plt.xlabel("Date")
#plt.ylabel("% of assets whose scenarios cover actuals from below")
#plt.title("Wind Coverage From Below at Asset Level Across Time (ORFEUS)")
#plt.tight_layout()
#plt.savefig("C:\\Users\\Mahashweta Patra\\Documents\\MikeLudkovski\\Output\\Percentiles\\IntraDayNew1\\Figure\\WindCoverageIntraDayNew1.png", dpi=300)

# %%
from numpy import mean
WindMean = mean(WindScenarios)
SolarMean = mean(SolarScenarios)
LoadMean = mean(LoadScenarios)

# %%
import numpy as np
import matplotlib.pyplot as plt
#print(SolarScenarios)
#      ['2020-01-20 08:00:00+00:00'].shape)
print(GenerationCost.shape)

time=WindScenarios.keys()
print(time.shape)
SumWindScenarios=WindScenarios[time[0]]
for i in range(1,23):
    W=WindScenarios[time[i]]
    SumWindScenarios=SumWindScenarios+W
    
print(SumWindScenarios.shape)

SumSolarScenarios=SolarScenarios[time[0]]
for i in range(1,23):
    W=SolarScenarios[time[i]]
    SumSolarScenarios=SumSolarScenarios+W
    
print(SumSolarScenarios.shape)


fig = plt.figure(figsize=(15,3))

ax = fig.add_subplot(1,2,1)
plt.scatter(SumWindScenarios, GenerationCost)
plt.xlabel("Aggregated Scenarios",fontsize=15)
plt.ylabel("Generation Cost",fontsize=15)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,2,2)
plt.scatter(SumSolarScenarios, GenerationCostSolar)
#plt.xlim([0.002, 0.003])
plt.xlabel("Aggregated Solar Scenarios",fontsize=15)
plt.ylabel("Generation Cost Solar",fontsize=15)
ax.tick_params(labelsize=15)

plt.tight_layout()
plt.savefig("C:\\Users\\Mahashweta Patra\\Documents\\MikeLudkovski\\ORFEUSRTS\\type-pwrset-jan20-20211229T210546Z-001\\type-pwrset-jan20\\Figures\\ScenarioGenCostScatter.png", dpi=300)
# Out:
# (1000,)
# (24,)
# (1000,)
# (1000,)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(WindScenarios)
principalDfWind = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2',  'principal component 3'])

principalComponents = pca.fit_transform(SolarScenarios)
principalDfSolar = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2', 'principal component 3'])

# %%
#print(principalDf['principal component 1'])
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,3))

ax = fig.add_subplot(1,2,1)
plt.scatter(principalDfWind['principal component 1'], principalDfWind['principal component 2'])
plt.xlabel("pc 1",fontsize=15)
plt.ylabel("pc 2",fontsize=15)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,2,2)
plt.scatter(principalDfSolar['principal component 1'], principalDfSolar['principal component 2'])
plt.xlabel("pc 1",fontsize=15)
plt.ylabel("pc 2",fontsize=15)
ax.tick_params(labelsize=15)

# %%
#print(principalDf['principal component 1'])
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,3))

ax = fig.add_subplot(1,2,1)
plt.scatter(GenerationCost, principalDfWind['principal component 2'])
plt.xlabel("Aggregated Wind Scenarios",fontsize=15)
plt.ylabel("pc 2",fontsize=15)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,2,2)
plt.scatter(GenerationCostSolar, principalDfSolar['principal component 2'])
plt.xlabel("Aggregated Solar Scenarios",fontsize=15)
plt.ylabel("pc 2",fontsize=15)
ax.tick_params(labelsize=15)

# %%
#print(principalDf['principal component 1'])
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,3))

ax = fig.add_subplot(1,2,1)
plt.scatter(GenerationCost, principalDfWind['principal component 3'])
plt.xlabel("Aggregated Wind Scenarios",fontsize=15)
plt.ylabel("pc 3",fontsize=15)
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,2,2)
plt.scatter(GenerationCostSolar, principalDfSolar['principal component 3'])
plt.xlabel("Aggregated Solar Scenarios",fontsize=15)
plt.ylabel("pc 3",fontsize=15)
ax.tick_params(labelsize=15)

# %%
import matplotlib.pyplot as plt
#plt.figure()
fig = plt.figure(figsize=(15,3))
ax = fig.add_subplot(1,3,1)
ax.set_ylabel("Wind Scenarios Mean",fontsize=15)
plt.plot(WindMean.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,2)
ax.set_ylabel("Solar Scenarios Mean",fontsize=15)
plt.plot(SolarMean.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

ax = fig.add_subplot(1,3,3)
ax.set_ylabel("Load Scenarios Mean",fontsize=15)
plt.plot(LoadMean.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

# %%
Difference=LoadMean-WindMean-SolarMean
import matplotlib.pyplot as plt
#plt.figure()
fig = plt.figure(figsize=(15,3))
ax = fig.add_subplot(1,3,1)
ax.set_ylabel("Difference",fontsize=15)
plt.plot(Difference.T,'b')
plt.show
plt.grid()
ax.tick_params(labelsize=15)

# %%
# Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import math
a=0.05
LoadMeanThresold=0.05*LoadMean
plt.plot(Difference.T,'b', label='Difference')
plt.plot(LoadMeanThresold.T,'r', label='5% Load Average')

plt.show()
